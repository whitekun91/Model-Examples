# %%
from utils.visualization import *
from AR.EDA.data_stationarity import acf_and_plotting
from AR.Models.AR import auto_regressive, predict_value

# %% [markdown]
# # Load Dataset

# %%
temp = pd.read_csv('./raw_dataset/temperature.csv')

# %%
temp.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
time_series_data_visualization(temp, 'Date', 'Temp')

# %% [markdown]
# # EDA (data stationarity - auto correlation)

# %%
acf_and_plotting(temp, 'Temp', 10)
# Out:
#      t-1  t+1
# t-1  1.0  1.0
# t+1  1.0  1.0

# %% [markdown]
# # Auto Regressive Model

# %%
model, train, test = auto_regressive(temp, 'Temp', 365, 1, 100)
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                   Temp   No. Observations:                 3285
# Model:                   AutoReg(100)   Log Likelihood               -7241.207
# Method:               Conditional MLE   S.D. of innovations              2.350
# Date:                Wed, 21 Aug 2024   AIC                          14686.413
# Time:                        21:25:18   BIC                          15305.167
# Sample:                           100   HQIC                         14908.301
#                                  3285
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7531      0.212      8.258      0.000       1.337       2.169
# Temp.L1        0.5647      0.018     31.889      0.000       0.530       0.599
# Temp.L2       -0.0942      0.020     -4.630      0.000      -0.134      -0.054
# ...

# %%
predict_value(model, train, test)
# Out:
# MSE :  9.012965717749823
# MAE :  2.330445147829855
